# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import chromedriver_binary  # This automatically handles ChromeDriver for you
import platform
import socket
import pdfplumber
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import chromedriver_binary  # This automatically handles ChromeDriver for you
import os
import time
from os import walk
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
def run(temp,email,password,title,price,dis,loc,tags):
    #market 
    time.sleep(3)
    driver.get("https://www.facebook.com/marketplace/create/item")
    try:
        driver.maximize_window()
    except:
        print("Already max size window")
    driver.refresh()
    time.sleep(10)
    try:
        s = driver.find_element("xpath","//input[@type='file']")
        s.send_keys(temp)
        time.sleep(5)
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Title']").send_keys(title)
        time.sleep(2)
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Price']").send_keys(price)
        time.sleep(2)
    except Exception as error:
        print(error)
        driver.find_element("xpath","//div[@class='x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x1q0g3np x87ps6o x1lku1pv x1a2a7pz x78zum5 x1iyjqo2']").click()
        time.sleep(3)
        pyautogui.write(temp)
        pyautogui.press('enter')
        time.sleep(2)
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Title']").send_keys(title)
        time.sleep(2)
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Price']").send_keys(price)
        time.sleep(2)
    try:
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Category']").click()
        time.sleep(1)
        driver.find_element("xpath","//span[text()='Furniture']").click()
    except:
        print("Category not found")
    time.sleep(2)
    driver.find_element(By.CSS_SELECTOR,"[aria-label='Condition']").click()
    time.sleep(2)
    driver.find_element("xpath","//div[@class='x6s0dn4 x78zum5 x1q0g3np x1iyjqo2 x1qughib xeuugli']").click()
    time.sleep(2)
    driver.find_element(By.CSS_SELECTOR,"[aria-label='Description']").send_keys(dis)
    time.sleep(3)
    p=driver.find_elements("xpath","//div[@class='xod5an3 x16n37ib x14vqqas x1n2onr6 xqcrz7y']")
    for j in range(len(p)):
        if j==(len(p)-1):
            p[j].click()
    time.sleep(3)
    i=driver.find_element(By.CSS_SELECTOR,"[aria-label='Location']")
    i.send_keys(Keys.CONTROL + "a")
    i.send_keys(Keys.DELETE)
    i.send_keys(loc)
    time.sleep(2)
    driver.find_element(By.CSS_SELECTOR,"[aria-label='Location']").click()
    #select first
    time.sleep(2)
    driver.find_element(By.CSS_SELECTOR, "[role='option']:first-child").click()
    time.sleep(2)
    for i in tags:
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Product tags']").send_keys(i)
        driver.find_element(By.CSS_SELECTOR,"[aria-label='Product tags']").send_keys(Keys.ENTER)
        time.sleep(1)
    driver.find_element(By.CSS_SELECTOR,"[aria-label='Next']").click()
    time.sleep(8)
    driver.find_element(By.CSS_SELECTOR,"[aria-label='Publish']").click()
    time.sleep(8)
def loc():
    file1 = open(path+"\\POSTCODES.txt", 'r')
    lines = file1.readlines()
    return lines

# %%
hostname=socket.gethostname()
my_system = platform.uname()
IPAddr=my_system.processor
with pdfplumber.open(r'INFO.pdf' , password = 'exe12345') as pdf:
    first_page = pdf.pages[0]
    xinf=(first_page.extract_text())
xinf=xinf.split()
xf=' '.join(xinf[1:])
if (xinf[0]!=hostname or xf!=IPAddr):
    print("Exccess Denied")
    ch=0
else:
    ch=1

# %%
if (ch==1):
    email=input("enter email : ")
    password=input("enter password : ")
    title=input("enter product name : ")
    title="TOP QUALITY BRAND NEW "+title+" cash on delivery"
    price=input("enter product Price : ")
    tags="Sofa","Furniture","Corner","Left","Right","1 seater","2 seater","3 seater","Footstool","Puffy","Chair","Brand New","Delivery","Free Delivery","Top Quality","Fabric","Velvet"
    dis="For order inbox me. It is available in different colors. Other sofas are also available. New designs, Modern looks, Comfortable seats, Brand new condition. Feel free to contact. I am always available for your services. You are welcomed  any time."
    path = os.getcwd()
    locate=loc()

# %%
if(ch==1):
    inp=input("enter Profile Number : ")
    url = 'http://www.facebook.com'
    # Create a ChromeOptions object
    chrome_options = webdriver.ChromeOptions()

    # Specify the user-data-directory to access the created profile
    chrome_options.add_argument(f'--user-data-dir=D:\softwear\chromeprofile{inp}')

    # Create a Chrome WebDriver with the configured options
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url)
    try:
        driver.find_element("name", "email").send_keys(email)
        time.sleep(3)
        driver.find_element("name", "pass").send_keys(password)
        time.sleep(3)
        driver.find_element("name", "login").click()
    except:
        print("already opened")
    time.sleep(5)

# %%
while(ch==1):
    cccv=input("Press 1 to procceed as profile is open")
    f1 = next(walk(path+"//images"), (None, None, []))[2]
    count=0
    arr=[]
    arr1=[]
    for i in f1:
        try:
            temp=path+"\\images\\"+i
            run(temp,email,password,title,price,dis,locate[count],tags)
            count=count+1
        except:
            print(i)
            arr.append(i)
            arr1.append(count)
            count=count+1
    bug=input("Detected Error Press 1: ")
    bug=int(bug)
    if (bug==1):
        j=0
        for i in arr:
            temp=path+"\\images\\"+i
            run(temp,email,password,title,price,dis,locate[arr1[j]],tags)
            j=j+1
    print("-------------Completed-----------")
    print("----------waiting-----------")
    print("Kindly switch your account before pressing 1 if you want too or change images")
    print("Press 1 to update title")
    t=input("INPUT")
    t=int(t)
    if (t==1):
        title=input("enter product name : ")
        title="TOP QUALITY BRAND NEW "+title+" cash on delivery"
    ch=input("Press 1 for further processes: ")
    ch=int(ch)
    if (ch!=1):
        ch=0
        driver.close()
